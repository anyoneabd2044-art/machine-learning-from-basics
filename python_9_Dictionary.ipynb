# %% [markdown]
# <a href="https://colab.research.google.com/github/anyoneabd2044-art/machine-learning-from-basics/blob/main/python_9_Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dictionary

# %%
{"Name":"ABD","Gender":"Male"}
# Out:
# {'Name': 'ABD', 'Gender': 'Male'}

# %% [markdown]
# # RULES FOR DICTIONARY

# %% [markdown]
# # R1 : Dictionary has no indexing

# %% [markdown]
# #

# %% [markdown]
# # R2: Dictionary is a Mutable Types

# %% [markdown]
# #

# %% [markdown]
# # R3: Keys --> Immutable
# #     Values --> Mutable

# %% [markdown]
# #

# %% [markdown]
# # R4: Keys should be Unique

# %% [markdown]
# #

# %% [markdown]
#  *Mutable -> Lists / Sets/ Dictionary*
#
#  *Immutable --> String / Tuples /int / float / Boolean/ complex*

# %% [markdown]
# #  Creating a Dictionary

# %%
D = {}

# %%
D
# Out:
# {}

# %%
D = {"Name":"ABD","Gender":"Male"}

# %%
D
# Out:
# {'Name': 'ABD', 'Gender': 'Male'}

# %% [markdown]
# **Lists**

# %%
D1 = { [1,2,3]:"ABD"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-691433960.py in <cell line: 0>()
# ----> 1 D1 = { [1,2,3]:"ABD"}
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# **Tuples**

# %%
D1 = {(1,2,3):"ABD"}

# %%
D1
# Out:
# {(1, 2, 3): 'ABD'}

# %% [markdown]
# *Keys Should Be Unique*

# %%
D2 = {"Name":"Rahul","Name":"Rohit"}

# %%
D2
# Out:
# {'Name': 'Rohit'}

# %%
# repeating keys -->  hr key ka ek h instence rhega--> woh bhi recent wala

# %% [markdown]
# **2-D dictionary**

# %%
D3 = {"Name":"Rohit","College":"HIT","Marks":{"M1":56,"DS":78,"Eng":67}}

# %%
D3
# Out:
# {'Name': 'Rohit', 'College': 'HIT', 'Marks': {'M1': 56, 'DS': 78, 'Eng': 67}}

# %%
D1
# Out:
# {(1, 2, 3): 'ABD'}

# %% [markdown]
# *dictionary has no indexing*

# %%
D[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-3858647015.py in <cell line: 0>()
# ----> 1 D[0]
#
# KeyError: 0

# %%
D = {"Name":"ABD","Gender":"Male"}

# %% [markdown]
# # Accessing Items from a Dictionary

# %%
D['Name']
# Out:
# 'ABD'

# %%
D['Gender']
# Out:
# 'Male'

# %%
D
# Out:
# {'Name': 'ABD', 'Gender': 'Male'}

# %%
D3
# Out:
# {'Name': 'Rohit', 'College': 'HIT', 'Marks': {'M1': 56, 'DS': 78, 'Eng': 67}}

# %%
D3['Marks']
# Out:
# {'M1': 56, 'DS': 78, 'Eng': 67}

# %%
D3['Marks']['DS']
# Out:
# 78

# %% [markdown]
# # Using (.get) function

# %%
D
# Out:
# {'Name': 'Rahul', 'Gender': 'Male'}

# %%
D.get("Name")
# Out:
# 'Rahul'

# %% [markdown]
# # Editing a Dictionary

# %%
D
# Out:
# {'Name': 'ABD', 'Gender': 'Male'}

# %%
D['Name']='Rahul'

# %%
D
# Out:
# {'Name': 'Rahul', 'Gender': 'Male'}

# %%
D3 = {"Name":"Rohit","College":"HIT","Marks":{"M1":56,"DS":78,"Eng":67}}

# %%
D3['Marks']['DS']=65

# %%
D3
# Out:
# {'Name': 'Rohit', 'College': 'HIT', 'Marks': {'M1': 56, 'DS': 65, 'Eng': 67}}

# %% [markdown]
# # Adding new Key-Value Pairs

# %%
D
# Out:
# {'Name': 'Rahul', 'Gender': 'Male'}

# %%
D['Age']=22

# %%
D
# Out:
# {'Name': 'Rahul', 'Gender': 'Male', 'Age': 22}

# %%
D3
# Out:
# {'Name': 'Rohit', 'College': 'HIT', 'Marks': {'M1': 56, 'DS': 65, 'Eng': 67}}

# %%
D3['Marks']['M2']=2

# %%
D3
# Out:
# {'Name': 'Rohit',
#  'College': 'HIT',
#  'Marks': {'M1': 56, 'DS': 65, 'Eng': 67, 'M2': 2}}

# %% [markdown]
# # Deletion from a Dictionary

# %%
 D5= {}

# %%
del D5

# %%
D5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1847753546.py in <cell line: 0>()
# ----> 1 D5
#
# NameError: name 'D5' is not defined

# %%
D
# Out:
# {'Name': 'Rahul', 'Gender': 'Male', 'Age': 22}

# %%
del D ["Gender"]

# %%
D
# Out:
# {'Name': 'Rahul', 'Age': 22}

# %%
D.clear()

# %%
D
# Out:
# {}

# %% [markdown]
# # Operations in a Dictionary

# %%
D
# Out:
# {}

# %%
D1
# Out:
# {(1, 2, 3): 'ABD'}

# %%
D2
# Out:
# {'Name': 'Rohit'}

# %%
D3
# Out:
# {'Name': 'Rohit',
#  'College': 'HIT',
#  'Marks': {'M1': 56, 'DS': 65, 'Eng': 67, 'M2': 2}}

# %%
D1+D2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2965468188.py in <cell line: 0>()
# ----> 1 D1+D2
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
D1*3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-4267963069.py in <cell line: 0>()
# ----> 1 D1*3
#
# TypeError: unsupported operand type(s) for *: 'dict' and 'int'

# %% [markdown]
# *Loop*

# %%
for i in D3:
  print(i)
# Out:
# Name
# College
# Marks

# %%
for i in D3:
  print(i,D3[i])
# Out:
# Name Rohit
# College HIT
# Marks {'M1': 56, 'DS': 65, 'Eng': 67, 'M2': 2}

# %%
"Rohit" in D3
# Out:
# False

# %%
'Name' in D3
# Out:
# True

# %%
len(D3)
# Out:
# 3

# %%
min(D3)
# Out:
# 'College'

# %%
max(D3)
# Out:
# 'Name'

# %%
sorted(D3)
# Out:
# ['College', 'Marks', 'Name']

# %%
sorted(D3,reverse=True)
# Out:
# ['Name', 'Marks', 'College']

# %%
D3
# Out:
# {'Name': 'Rohit',
#  'College': 'HIT',
#  'Marks': {'M1': 56, 'DS': 65, 'Eng': 67, 'M2': 2}}

# %%
D3.keys()
# Out:
# dict_keys(['Name', 'College', 'Marks'])

# %%
D3.values()
# Out:
# dict_values(['Rohit', 'HIT', {'M1': 56, 'DS': 65, 'Eng': 67, 'M2': 2}])
