# %% [markdown]
# <a href="https://colab.research.google.com/github/anyoneabd2044-art/machine-learning-from-basics/blob/main/python4_built_in_module.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Modules

# %%
# What are modules?
#  consider a module to be same as a code library.

# a file containing a set of functions you want to include inn your application.

# Example of python modules:
# :Maths
# :Random
# :OS
# :Time
# for code reuseability we use modules

# %%
help('modules')

# %% [markdown]
# # math modules

# %%
# include<stdio.h>
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.factorial(5)
# Out:
# 120

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.ceil(6.3)
# Out:
# 7

# %%
math.floor(6.3)
# Out:
# 6

# %% [markdown]
# # random modules

# %%
import random

# %%
random.randint(1,100)
# Out:
# 34

# %%
a = [1,2,3,4,5]
random.shuffle(a)
a
# Out:
# [3, 5, 4, 1, 2]

# %% [markdown]
# # Time modules

# %%
import time

# %%
time.time()
# Out:
# 1759128727.5128725

# %%
time.ctime()
# Out:
# 'Mon Sep 29 06:52:36 2025'

# %%
print('hello')
time.sleep(4)
print('world')
# Out:
# hello
# world

# %% [markdown]
# # OS modules

# %%
import os

# %%
os.getcwd()
# Out:
# '/content'

# %%
os.listdir()
# Out:
# ['.config', 'sample_data']
