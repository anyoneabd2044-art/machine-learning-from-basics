# %% [markdown]
# <a href="https://colab.research.google.com/github/anyoneabd2044-art/machine-learning-from-basics/blob/main/8python_SETS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SETS

# %% [markdown]
# *  Sets do not allow DUPLICATES.
# *  Sets have no Indexing/Sclicing.
# *  Sets don't allow Mutable DataType.
# *  Sets itself is a Mutable DataType.

# %% [markdown]
# # Creating a SET

# %%
S= {}

# %%
S
# Out:
# {}

# %%
type(S)
# Out:
# dict

# %%
S = set()

# %%
type(S)
# Out:
# set

# %%
S1 = {1,2,3,4,5}

# %%
S1
# Out:
# {1, 2, 3, 4, 5}

# %%
S2 = {"Hello",4.5,True}

# %%
S2
# Out:
# {4.5, 'Hello', True}

# %% [markdown]
# * Duplicates are not allowed

# %%
S3 = {1,1,2,2,3,3}

# %%
S3
# Out:
# {1, 2, 3}

# %% [markdown]
# * Sets don't allow mutable data type
# * [  ]->Lists ->mutable

# %%
S4 = {[1,2,3],"Hello"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2384955336.py in <cell line: 0>()
# ----> 1 S4 = {[1,2,3],"Hello"}
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# * ()->Tuples->Immutable

# %%
S4 = {(1,2,3),"Hello"}

# %%
S4
# Out:
# {(1, 2, 3), 'Hello'}

# %% [markdown]
# * Sets have no indexing
# * Hashing
# *

# %% [markdown]
# *  2-D Sets are not possible

# %%
S5 = {{1}, {2}}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-186470619.py in <cell line: 0>()
# ----> 1 S5 = {{1}, {2}}
#
# TypeError: unhashable type: 'set'

# %% [markdown]
# # Access items

# %% [markdown]
# *We can't access items from Sets*

# %%
S2
# Out:
# {4.5, 'Hello', True}

# %%
S1
# Out:
# {1, 2, 3, 4, 5}

# %%
S1[::-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-248395706.py in <cell line: 0>()
# ----> 1 S1[::-1]
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# # Edit

# %% [markdown]
# * we can't edit items of Sets

# %%
S1[2] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2261523821.py in <cell line: 0>()
# ----> 1 S1[2] = 100
#
# TypeError: 'set' object does not support item assignment

# %%
S1
# Out:
# {1, 2, 3, 4, 5}

# %%
id(S1)
# Out:
# 135869305679296

# %%
L=list(S1)

# %%
L
# Out:
# [1, 2, 3, 4, 5]

# %%
L[0]=100

# %%
L
# Out:
# [100, 2, 3, 4, 5]

# %%
S1 = set(L)

# %%
S1
# Out:
# {2, 3, 4, 5, 100}

# %%
id(S1)
# Out:
# 135869305682880

# %% [markdown]
# # Add

# %% [markdown]
# *Yes we can add items in sets using add function*

# %%
S1
# Out:
# {2, 3, 4, 5, 100}

# %%
S1.add(6)

# %%
S1
# Out:
# {2, 3, 4, 5, 6, 100}

# %%
id(S1)
# Out:
# 135869305682880

# %%
S1.add(7)

# %%
S1
# Out:
# {2, 3, 4, 5, 6, 7, 100}

# %% [markdown]
# * sets itself is a mutable data type

# %% [markdown]
# # Delete

# %% [markdown]
# * del
# * remove
# * pop

# %%
S
# Out:
# set()

# %%
del S

# %%
S
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2324250724.py in <cell line: 0>()
# ----> 1 S
#
# NameError: name 'S' is not defined

# %% [markdown]
# *  we can only delete the whole set as it don't allow indexing/slicing

# %%
del S1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2134711622.py in <cell line: 0>()
# ----> 1 del S1[0]
#
# TypeError: 'set' object doesn't support item deletion

# %%
S1
# Out:
# {2, 3, 4, 5, 6, 7, 100}

# %%
S1.remove(100)

# %%
S1
# Out:
# {2, 3, 4, 5, 6, 7}

# %%
S1.pop()
# Out:
# 2

# %%
S1.pop()
# Out:
# 3

# %%
S1
# Out:
# {4, 5, 6, 7}

# %% [markdown]
# # SETS Operations

# %%
S1 = {1,2,3,4,5}
S2 = {3,4,5,6,7}

# %%
S1+S2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3940363174.py in <cell line: 0>()
# ----> 1 S1+S2
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
S1*3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-424011571.py in <cell line: 0>()
# ----> 1 S1*3
#
# TypeError: unsupported operand type(s) for *: 'set' and 'int'

# %%
for i in S1:
  print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
1 in S1
# Out:
# True

# %%
3 in S2
# Out:
# True

# %% [markdown]
# # Sets Functions

# %% [markdown]
# *  len
# *  min
# *  max
# *  sum
# *  sorted
# *  sorted(X,reverse=True)
# *  Union
# *  Intersection
# *  difference
# *  difference
# *  symmetric_difference
# *  isdisjoint
# *  issubset
# *  issuperset

# %%
len(S1)
# Out:
# 5

# %%
min(S1)
# Out:
# 1

# %%
max(S1)
# Out:
# 5

# %%
sorted(S1)
# Out:
# [1, 2, 3, 4, 5]

# %%
sorted(S1,reverse=True)
# Out:
# [5, 4, 3, 2, 1]

# %%
sum(S1)
# Out:
# 15

# %%
S1
# Out:
# {1, 2, 3, 4, 5}

# %%
S2
# Out:
# {3, 4, 5, 6, 7}

# %%
S1.union(S2)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
S1.intersection(S2)
# Out:
# {3, 4, 5}

# %%
S1.difference(S2)
# Out:
# {1, 2}

# %%
S2.difference(S1)
# Out:
# {6, 7}

# %%
S1.symmetric_difference(S2)
# Out:
# {1, 2, 6, 7}

# %%
S1.isdisjoint(S2)
# Out:
# False

# %%
S1.issubset(S2)
# Out:
# False

# %%
S1.issuperset(S2)
# Out:
# False

# %%
S1
# Out:
# {1, 2, 3, 4, 5}

# %%
S1.clear()

# %%
S1
# Out:
# set()
