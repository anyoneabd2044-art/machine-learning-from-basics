# %% [markdown]
# <a href="https://colab.research.google.com/github/anyoneabd2044-art/machine-learning-from-basics/blob/main/python_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Variable and Memory References

# %%
# value in variable-->run --> physically --> device--> ram--> memory allocate hota hai

# %%
#  when our program is at rest --> it is in --> Rom(hard disk)

# %%
# when our program start to run -->it load in --> Ram--> and started allocating linebyline

# %% [markdown]
# *Every Thing Is Inside Ram*

# %% [markdown]
# **As Ram is Volatile---> IF we off the program / machine , the memory occupied is removed**

# %% [markdown]
# *Where does everything is Stored In Ram*

# %% [markdown]
# **It Is Stored In REGiSTERS**

# %% [markdown]
# #
# #

# %% [markdown]
# *REGISTER are tiny storage unit inside CPU*

# %% [markdown]
# *RAM is a seperate memory system made of capacitors or flip-flops on memory chips*

# %% [markdown]
# **CPU reads/write data from RAM into registers when performing operations**

# %% [markdown]
# #
# #

# %% [markdown]
# **CPU always tries to load data from RAM into register for Computation**

# %% [markdown]
# **Register is a very small, very fast memory storage built inside the CPU**

# %%
# When We Create a "Variable"--> Pyhton called it "Name"

# %%
a
# Out:
# 'HELLOworld'

# %%
a = 4

# %%
id(a)
# Out:
# 11654472

# %%
hex(11642184)
# Out:
# '0xb1a548'

# %%
id(4)
# Out:
# 11654472

# %%
# When We Are Creating a "Name"--> It Is Actually "Pointing To The Address" of That Particular Thing

# %% [markdown]
# **Call By Object Reference**

# %% [markdown]
# *Call by Object Reference--> Pointing toward the value/address*

# %% [markdown]
# #
# #

# %% [markdown]
# # Aliasing

# %%
a = 5

# %%
b = a

# %%
c = b

# %%
id(a)
# Out:
# 11654504

# %%
id(b)
# Out:
# 11654504

# %%
id(c)
# Out:
# 11654504

# %%
del a

# %%
id(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-56049622.py in <cell line: 0>()
# ----> 1 id(a)
#
# NameError: name 'a' is not defined

# %%
b
# Out:
# 5

# %%
del b

# %%
id(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1651017570.py in <cell line: 0>()
# ----> 1 id(b)
#
# NameError: name 'b' is not defined

# %%
id(c)
# Out:
# 11654504

# %%
a=5

# %%
b=a

# %%
a=6

# %%
b
# Out:
# 5

# %% [markdown]
# # Reference Counting

# %%
import sys

# %%
a ="corona"

# %%
b = a

# %%
c = b

# %%
id(a)
# Out:
# 135606217334944

# %%
id(b)
# Out:
# 135606217334944

# %%
id(c)
# Out:
# 135606217334944

# %%
sys.getrefcount(a)
# Out:
# 4

# %% [markdown]
# # Garbage Collection

# %% [markdown]
# **Garbage Collection: is a process by which python automatically frees up memory by removing objects that are no longer in use**

# %% [markdown]
# *When we create variables, lists, dictionaries, etc. python stores them in memory(RAM). If you don't need them anymore, but they still stays in memory, your program will waste mempry.*

# %% [markdown]
# **Garbage Collector: python's gc module control the garbage collection process. It helps manage cyclic references-situations where two or more objects refers to each other**

# %% [markdown]
# # Weird Stuff

# %% [markdown]
# **WB1**

# %%
a = 2

# %%
b = a

# %%
c = b

# %%
sys.getrefcount(a)
# Out:
# 4294967295

# %% [markdown]
# *Reason for weird value: The integer 2 is an interned object used all over Python; its reference count can overflow or brhave unexpectedly*

# %% [markdown]
# *The huge number(4294967295):This is an overflowed 32 bit unsigned integer value-not an actual reference count*

# %% [markdown]
# **WB2**

# %%
a = 4

# %%
b = 4

# %%
sys.getrefcount(a)
# Out:
# 4294967295

# %%
sys.getrefcount(b)
# Out:
# 4294967295

# %% [markdown]
# *It is Python reference count overflow issue.*

# %% [markdown]
# *This happenes because: .Small integer like 0-256 are interned (Python keeps a a single shared copy of these values in memory for eficiency)*

# %% [markdown]
# *These small integer are used everywhere in Python-inside loops, constant, function calls, etc.*

# %% [markdown]
# **So their reference count become extremely large**

# %% [markdown]
# **The Real Reference Count is too large to fit in a 32-bit integer-it overflowed**

# %%
a  = 256

# %%
b = 256

# %%
id(a)
# Out:
# 11662536

# %%
id(b)
# Out:
# 11662536

# %%
a = 257

# %%
b = 257

# %%
id(a)
# Out:
# 135606217855536

# %%
id(b)
# Out:
# 135606217856112

# %% [markdown]
# **This is "integer caching" or "interning"**

# %% [markdown]
# *This happenes beause: Python automatically caches(or interns)small integer objects in memory to save space and improve performance*

# %% [markdown]
# *The range of cached integer is [-5,256]*

# %% [markdown]
# **Integer between -5 and 256 are pre-created and reused by Python.**

# %% [markdown]
# **Integer outside this range are created as new object each time**

# %%
a = "haldia"

# %%
b ="haldia"

# %%
id(a)
# Out:
# 135606217339216

# %%
id(b)
# Out:
# 135606217339216

# %%
a = "haldia inst tech"

# %%
b = "haldia inst tech"

# %%
id(a)
# Out:
# 135606218035312

# %%
id(b)
# Out:
# 135606218035632

# %%
a = "haldia_inst_tech"

# %%
b = "haldia_inst_tech"

# %% [markdown]
# *This is not a valid identifier*

# %%
id(a)
# Out:
# 135606218036784

# %%
id(b)
# Out:
# 135606218036784

# %% [markdown]
# **This will happens when there is a "Valid identifier"**

# %% [markdown]
# *valid identifier: starts with alph or have underscore*

# %%
L=[1,2,3]

# %%
id(L)
# Out:
# 135606218036352

# %%
id(L[0])
# Out:
# 11654376

# %%
id(1)
# Out:
# 11654376

# %%
id(2)
# Out:
# 11654408

# %%
id(3)
# Out:
# 11654440

# %%
L[2]=1

# %%
id(L[2])
# Out:
# 11654376

# %%
L=[1,2,3,[4,5]]

# %%
L
# Out:
# [1, 2, 3, [4, 5]]

# %% [markdown]
# # *Mutability*

# %% [markdown]
# **Mutability refers to the ability to change or edit data in it's memory location**

# %%
a = "HELLO"

# %%
id(a)
# Out:
# 135606217839152

# %%
a = a+"world"

# %%
a
# Out:
# 'HELLOworld'

# %%
id(a)
# Out:
# 135606218038384

# %%
T = (1,2,3)

# %%
id(T)
# Out:
# 135606219049792

# %%
T = T +(5,6)

# %%
T
# Out:
# (1, 2, 3, 5, 6)

# %%
id(T)
# Out:
# 135606219081744

# %% [markdown]
# **immutable_data_type = String , int , float , Bool , Complex , Tuplet**

# %%
print(immutable_data_type)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2578583875.py in <cell line: 0>()
# ----> 1 print(immutable_data_type)
#
# NameError: name 'immutable_data_type' is not defined

# %% [markdown]
# **mutable_data_type = (List,Set,Dictionary)**

# %%
print(mutable_data_type)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-661020417.py in <cell line: 0>()
# ----> 1 print(mutable_data_type)
#
# NameError: name 'mutable_data_type' is not defined

# %%
L = [1,2,3]

# %%
L
# Out:
# [1, 2, 3]

# %%
id(L)
# Out:
# 135606217734336

# %%
L.append(4)

# %%
L
# Out:
# [1, 2, 3, 4]

# %%
id(L)
# Out:
# 135606217734336

# %% [markdown]
# # **Side Effect Of Mutation**

# %% [markdown]
# *Like while working and we need to copy something if we do Aliasing then the previous data will be affected*

# %% [markdown]
# *agr kisi ko tmne apne data diya aur usne append yh aliasing kr diya toh dono data mutated ho jyga aur dono change hoga isse previous data change ho jyga aur dikkat hogi isse bachne k liye CLONING k use krte hai  *

# %%
L =[1,2,3]

# %%
L1 = L

# %%
L1
# Out:
# [1, 2, 3]

# %%
L
# Out:
# [1, 2, 3]

# %%
id(L)
# Out:
# 135606217684864

# %%
id(L1)
# Out:
# 135606217684864

# %%
L1.append(4)

# %%
L1
# Out:
# [1, 2, 3, 4]

# %%
id(L1)
# Out:
# 135606217684864

# %%
L
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# # *Cloning*

# %%
L
# Out:
# [1, 2, 3, 4]

# %%
L1 = L[:]

# %%
id(L)
# Out:
# 135606217684864

# %%
id(L1)
# Out:
# 135606217679744

# %%
L1.append(5)

# %%
L1
# Out:
# [1, 2, 3, 4, 5]

# %%
L
# Out:
# [1, 2, 3, 4]

# %%
a = (1,2,3,[4,5])

# %%
a
# Out:
# (1, 2, 3, [4, 5])

# %%
a[-1][-1]=500

# %% [markdown]
# *will it happen or not*

# %% [markdown]
# **Yes, it will happen b/s last cell is list an dit is mutable**

# %%
a
# Out:
# (1, 2, 3, [4, 500])

# %%
a = [1,2,3,(4,5)]

# %%
a[-1][-1]=500
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2549356361.py in <cell line: 0>()
# ----> 1 a[-1][-1]=500
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# will it happen

# %% [markdown]
# no

# %%
a
# Out:
# [1, 2, 3, (4, 5)]

# %%
a = [1,2]

# %%
b = [3,4]

# %%
c = (a,b)

# %%
c
# Out:
# ([1, 2], [3, 4])

# %%
id(a)
# Out:
# 135606217976256

# %%
id(b)
# Out:
# 135606217882816

# %%
id(c)
# Out:
# 135606217220480

# %% [markdown]
# will this code work

# %%
c[0][0]=100

# %% [markdown]
# yes it will b/s firt element is made of sets and set is matable

# %%
c
# Out:
# ([100, 2], [3, 4])

# %% [markdown]
# will the id of a,b,c will change ?

# %% [markdown]
# no

# %%
id(a)
# Out:
# 135606217976256

# %%
id(b)
# Out:
# 135606217882816

# %%
id(c)
# Out:
# 135606217220480

# %%
c[0]=c[0]+[5,6]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-424104960.py in <cell line: 0>()
# ----> 1 c[0]=c[0]+[5,6]
#
# TypeError: 'tuple' object does not support item assignment

# %%
c
# Out:
# ([100, 2], [3, 4])

# %%
c = c +(5,6)

# %%
c
# Out:
# ([100, 2], [3, 4], 5, 6)

# %%
a
# Out:
# [100, 2]

# %%
a =a+[5,6]

# %%
a
# Out:
# [100, 2, 5, 6]
